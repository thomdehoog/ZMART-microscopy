# %% [markdown]
# # Example experiment on the controller
#
# The general flow a workflow follows on top of the controller. It talks only to
# the controller - never a vendor API - so the same notebook runs against any
# microscope that has a driver.
#
# 1. connect - pick an instrument and set the frame
# 2. select states - capture a configuration per scan mode
# 3. get positions - the positions to visit
# 4. acquire - set a mode, then for each position: set_xyz, acquire (captures + saves)

# %% [markdown]
# ## Setup
#
# Register the bundled **mock driver** so the flow runs with no hardware. Run this
# notebook with its own folder as the working directory.

# %%
import sys
from pathlib import Path

here = Path.cwd()  # .../controller
sys.path.insert(0, str(here.parents[0]))  # repo root (parent of the package)
sys.path.insert(0, str(here / "tests"))  # the mock driver

import mock_driver  # noqa: E402

mock_driver.register_mock()

# %% [markdown]
# ## 1. Connect and set the frame
#
# `get_instruments()` lists what you can connect to as connection dicts (touching no
# hardware). Pick one, `set_instrument()` opens the session, and `set_origin()` sets
# the frame origin at the current position. Every position is micrometers in that
# frame. From here, `controller` is that microscope.

# %%
import controller

controller.get_instruments()

# %%
instrument = controller.get_instruments()[0]
controller.set_instrument(instrument)
controller.set_origin()  # (0, 0, 0) is here now

# %% [markdown]
# ## 2. Select states
#
# A **state** is a snapshot of the instrument you can reapply later: an `immutable`
# fingerprint plus a `mutable` part. It is opaque to the controller - only the
# driver interprets it. We capture two modes, one cell each.

# %%
# a gentle overview scan
prescan = controller.get_state()
prescan["mutable"]["laser_power"] = 2.0
prescan

# %%
# a higher-power detailed scan
target = controller.get_state()
target["mutable"]["laser_power"] = 8.0
target["mutable"]["gain"] = 2.0
target

# %% [markdown]
# ## 3. Get the positions
#
# `get_context()` returns whatever extra context the driver provides; here that
# includes the positions captured at connect.

# %%
positions = controller.get_context()["initial_positions"]
positions

# %% [markdown]
# ## 4. Acquire
#
# Reapply a state, then run every position. `set_xyz` moves in micrometers from the
# origin (`with_actuators` picks the actuator per axis - here the piezo for fine Z).
# `acquire` captures **and** saves in one call: `acquisition_type` is the scan kind,
# `position_label` names the output, and `options` (from `get_acquisition_options()`)
# carries acquisition + saving settings. Re-run with `controller.set_state(target)` for the
# target scan.

# %%
controller.set_state(prescan)

# %%
for i, pos in enumerate(positions):
    controller.set_xyz(pos["x"], pos["y"], pos["z"], with_actuators={"z": "piezo"})
    record = controller.acquire(acquisition_type="prescan", position_label=f"pos_{i:03d}")
    print(record)

# %% [markdown]
# ## Done
#
# Close the session. The mock has nothing to release, but a real driver may need
# the teardown.
#
# ---
#
# *Author: Thom de Hoog — Center for Microscopy and Image Analysis (ZMB),
# University of Zurich (thom.dehoog@zmb.uzh.ch, thomdehoog@gmail.com).*

# %%
controller.disconnect()
