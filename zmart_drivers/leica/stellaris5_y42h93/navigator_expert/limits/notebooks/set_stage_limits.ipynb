# %% [markdown]
# # Set stage limits
#
# Edit the physical envelope and run. This publishes `limits.json` into ProgramData.

# %%
import _bootstrap
from navigator_expert.motion import stage_config

stage_config.adopt_limits(
    {
        "x": [1000, 130000],
        "y": [1000, 100000],
        "z_galvo": [-200, 200],
        "z_wide": [0, 25000],
    },
    notebook_paths=[_bootstrap.NOTEBOOK_PATH],
)
